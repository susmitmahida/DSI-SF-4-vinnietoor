# %% [markdown]
# ## Vinnie's capstone ideas

# %% [markdown]
# ### Idea #1
# Found data on ncaa sports team revenue and expenses. Wanted to find out if the players deserve compensation for the revenue they are responsible for and how much compensation they deserve. A problem I already see is that each player has a different contribution towards the revenue that their sports team brings to the college. Might be difficult to calculate each individual's worth to the team.

# %% [markdown]
# ### Idea #2
# Using this data and maybe finding some more, I could try to predict how much revenue and expense a certain college is going to have in the upcoming year and also find out why certain school's sports teams are bringing in more revenue or have more expenses than the others. This would be useful for schools that are less profitable.

# %% [markdown]
# Link to dataset zip files:
# https://github.com/AragornTech/ncaa_data/tree/master/doe_2000_2013/business_week_data

# %%
import pandas as pd

# %%
entire = pd.read_csv('../../Downloads/all_institution_data_10_13.csv')

# %%
for col in entire:
    print col
entire.head()
# Out:
# school
# unitid
# sport
# year
# total_profit
# men_profit
# women_profit
# total_expense
# total_women_including_coed_expense
# total_men_including_coed_expense
# coed_expense
# women_coed_expense
# men_coed_expense
# women_men_expense
# women_expense
# men_expense
# total_revenue
# women_including_coed_revenue
# men_including_coed_revenue
# coed_revenue
# women_coed_revenue
# men_coed_revenue
# total_men_women_revenue
# women_revenue
# men_revenue
# total_team_expense
# total_women_team_expense_including_coed
# total_men_team_expense_including_coed
# total_coed_team_expense
# total_women_coed_team_expense
# total_men_coed_team_expense
# total_men_women_team_expense
# men_team_expense
# total_female_athletes_including_coed
# total_male_athletes_including_coed
# female_coed_athletes
# male_coed_athletes
# female_athletes
# male_athletes
# start_year
# end_year
# sportcode
# women_team_expense
# coed_athletes
# sport_label
# association
# conference
# ...

# %%
rev_by_conf = pd.read_csv('../../Downloads/by_conference/total_by_ncaa_type_sport_type_conference.csv')

# %%
for col in rev_by_conf:
    print col
rev_by_conf.head()
# Out:
# year
# conference
# association
# sport_label
# men_revenue
# women_revenue
# total_revenue
#         year                 conference        association  \
# 0  2000-2001  Atlantic Coast Conference  NCAA Division I-A
# 1  2000-2001  Atlantic Coast Conference  NCAA Division I-A
# 2  2000-2001  Atlantic Coast Conference  NCAA Division I-A
# 3  2000-2001          Big 12 Conference  NCAA Division I-A
# 4  2000-2001          Big 12 Conference  NCAA Division I-A
#
#                sport_label  men_revenue  women_revenue  total_revenue
# 0               Basketball     87117280        3371236       90488516
# 1                 Football    174225605              0      174225605
# 2  Non Football-Basketball     11641923        9703678       21345601
# 3               Basketball     35033722        4153392       39187114
# 4                 Football    118572258              0      118572258

# %%
rev_by_div = pd.read_csv('../../Downloads/by_ncaa/total_by_ncca_type_by_power_sport.csv')

# %%
rev_by_div
# Out:
#           year          association              sport_label   men_revenue  \
# 0    2000-2001    NCAA Division I-A               Basketball  4.259035e+08
# 1    2000-2001    NCAA Division I-A                 Football  1.236419e+09
# 2    2000-2001    NCAA Division I-A  Non Football-Basketball  9.465527e+07
# 3    2000-2001   NCAA Division I-AA               Basketball  5.732136e+07
# 4    2000-2001   NCAA Division I-AA                 Football  8.747804e+07
# 5    2000-2001   NCAA Division I-AA  Non Football-Basketball  4.619844e+07
# 6    2000-2001  NCAA Division I-AAA               Basketball  7.865116e+07
# 7    2000-2001  NCAA Division I-AAA                 Football  3.580527e+06
# 8    2000-2001  NCAA Division I-AAA  Non Football-Basketball  6.461102e+07
# 9    2000-2001     NCAA Division II               Basketball  3.238903e+07
# 10   2000-2001     NCAA Division II                 Football  4.047291e+07
# ...

# %%
rev_by_school = pd.read_csv('../../Downloads/by_school/total_by_all_sport_ncaa_type_school_conference.csv')

# %%
rev_by_school
# Out:
#              year      sport  \
# 0       2000-2001    Archery
# 1       2000-2001    Archery
# 2       2000-2001    Archery
# 3       2000-2001  Badminton
# 4       2000-2001   Baseball
# 5       2000-2001   Baseball
# 6       2000-2001   Baseball
# 7       2000-2001   Baseball
# 8       2000-2001   Baseball
# 9       2000-2001   Baseball
# 10      2000-2001   Baseball
# 11      2000-2001   Baseball
# 12      2000-2001   Baseball
# 13      2000-2001   Baseball
# 14      2000-2001   Baseball
# 15      2000-2001   Baseball
# 16      2000-2001   Baseball
# 17      2000-2001   Baseball
# 18      2000-2001   Baseball
# 19      2000-2001   Baseball
# 20      2000-2001   Baseball
# 21      2000-2001   Baseball
# 22      2000-2001   Baseball
# 23      2000-2001   Baseball
# 24      2000-2001   Baseball
# 25      2000-2001   Baseball
# 26      2000-2001   Baseball
# 27      2000-2001   Baseball
# 28      2000-2001   Baseball
# 29      2000-2001   Baseball
# ...           ...        ...
# ...
