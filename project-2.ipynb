# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 2
#
# ### Exploratory Data Analysis (EDA)
#
# ---
#
# This project is focused on exploratory data analysis (EDA). EDA is an essential part of the data science analysis pipeline. Failure to perform EDA before modeling is almost guaranteed to lead to pitfalls and faulty conclusions. What you do in this project are good practices for all projects going forward, especially those beyond this class!
#
# Problems 1 thru 6 use a small dataset on state SAT scores.
#
# Problems 7 thru 12 use a fraction of the Iowa Liquor Sales dataset (described in more detail in question 7).
#
# ---
#
# This project includes a variety of plotting problems. Much of the plotting code will be left up to you to find either in the lecture notes, or if not there, online. There are massive amounts of code snippets either in documentation or sites like stackoverflow that have almost certainly done what you are trying to do.
#
# **Get used to using google for finding code!** You will be using it every single day as a data scientist, especially for visualization and plotting.
#
# #### Package imports

# %%
import numpy as np
import scipy.stats as stats
import csv
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# this line tells jupyter notebook to put the plots in the notebook rather than saving them to file.
# %matplotlib inline

# this line makes plots prettier on mac retina screens. If you don't have one it shouldn't do anything.
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1. Load the `sat_scores.csv` dataset and describe it
#
# ---
#
# You should replace the placeholder path to the `sat_scores.csv` dataset below with your specific path to the file.
#
# ### 1.1 Load the file with the `csv` module and put in dictionary format.
#
# The dictionary format for data will be keys as the column names/headers, and values as the row values for that column.
#
# Toy example:
# ```python
# data = {
#     'column1':[0,1,2,3],
#     'column2':['a','b','c','d']
#     }
# ```

# %%
sat_filepath = '../../../../Desktop/DSI-SF-4-vinnietoor/datasets/state_sat_scores/sat_scores.csv'

# %%
with open(sat_filepath,'r') as f:
    data = [row.strip().split(',') for row in f]

data_dic = {row[0]:row[1:] for row in zip(*data)}
data_dic
# Out:
# {'Math': ('510',
#   '513',
#   '515',
#   '505',
#   '516',
#   '499',
#   '499',
#   '506',
#   '500',
#   '501',
#   '499',
#   '510',
#   '499',
#   '489',
#   '501',
#   '488',
#   '474',
#   '526',
#   '499',
#   '527',
#   '499',
#   '515',
#   '510',
#   '517',
#   '525',
#   '515',
#   '542',
#   '439',
#   '539',
#   '512',
#   '542',
#   '553',
#   '542',
#   '589',
#   '550',
#   '545',
#   '572',
#   '589',
#   '580',
#   '554',
#   '568',
#   '561',
#   '577',
#   '562',
#   '596',
#   '550',
#   '570',
#   '603',
#   '582',
#   '599',
#   '551',
#   '514'),
#  'Rate': ('82',
#   '81',
#   '79',
#   '77',
#   '72',
#   '71',
#   '71',
#   '69',
#   '69',
#   '68',
#   '67',
#   '65',
#   '65',
#   '63',
#   '60',
#   '57',
#   '56',
#   '55',
#   '54',
#   '53',
#   '53',
#   '52',
#   '51',
#   '51',
#   '34',
#   '33',
#   '31',
#   '26',
#   '23',
#   '18',
#   '17',
#   '13',
#   '13',
#   '12',
#   '12',
#   '11',
#   '11',
#   '9',
#   '9',
#   '9',
#   '8',
#   '8',
#   '8',
#   '7',
#   '6',
#   '6',
#   '5',
#   '5',
#   '4',
#   '4',
#   '4',
#   '45'),
#  'State': ('CT',
#   'NJ',
#   'MA',
#   'NY',
#   'NH',
#   'RI',
#   'PA',
#   'VT',
#   'ME',
#   'VA',
#   'DE',
#   'MD',
#   'NC',
#   'GA',
#   'IN',
#   'SC',
#   'DC',
#   'OR',
#   'FL',
#   'WA',
#   'TX',
#   'HI',
#   'AK',
#   'CA',
#   'AZ',
#   'NV',
#   'CO',
#   'OH',
#   'MT',
#   'WV',
#   'ID',
#   'TN',
#   'NM',
#   'IL',
#   'KY',
#   'WY',
#   'MI',
#   'MN',
#   'KS',
#   'AL',
#   'NE',
#   'OK',
#   'MO',
#   'LA',
#   'WI',
#   'AR',
#   'UT',
#   'IA',
#   'SD',
#   'ND',
#   'MS',
#   'All'),
#  'Verbal': ('509',
#   '499',
#   '511',
#   '495',
#   '520',
#   '501',
#   '500',
#   '511',
#   '506',
#   '510',
#   '501',
#   '508',
#   '493',
#   '491',
#   '499',
#   '486',
#   '482',
#   '526',
#   '498',
#   '527',
#   '493',
#   '485',
#   '514',
#   '498',
#   '523',
#   '509',
#   '539',
#   '534',
#   '539',
#   '527',
#   '543',
#   '562',
#   '551',
#   '576',
#   '550',
#   '547',
#   '561',
#   '580',
#   '577',
#   '559',
#   '562',
#   '567',
#   '577',
#   '564',
#   '584',
#   '562',
#   '575',
#   '593',
#   '577',
#   '592',
#   '566',
#   '506')}

# %% [markdown]
# ### 1.2 Make a pandas DataFrame object with the sat dictionary and also with the pandas `.read_csv()` function
#
# Compare the DataFrames using the `.dtypes` attribute in the DataFrame objects. What is the difference between loading from file and inputting this dictionary (if any)?

# %%
df_sat = pd.DataFrame(data_dic)
df = pd.read_csv(sat_filepath)
print df_sat.head()
print df.head()

print df['Math'].dtype
print df_sat['Math'].dtype
# Out:
#   Math Rate State Verbal
# 0  510   82    CT    509
# 1  513   81    NJ    499
# 2  515   79    MA    511
# 3  505   77    NY    495
# 4  516   72    NH    520
#   State  Rate  Verbal  Math
# 0    CT    82     509   510
# 1    NJ    81     499   513
# 2    MA    79     511   515
# 3    NY    77     495   505
# 4    NH    72     520   516
# int64
# object

# %% [markdown]
# If you did not convert the string column values to float in your dictionary, the columns in the DataFrame are of type `object` (which are string values).

# %% [markdown]
# ### 1.3 Look at the first ten rows of the DataFrame and describe what the data appears to be.
#
# From now on, use the DataFrame loaded from the file using the `.read_csv()` function.
#
# Use the `.head(num)` built-in DataFrame function, where `num` is the number of rows to print out.
#
# You are not given a "codebook" with this data, so you will have to make some (very minor) inference.

# %%
df.head(10)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 4 columns):
# State     52 non-null object
# Rate      52 non-null int64
# Verbal    52 non-null int64
# Math      52 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 1.7+ KB

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2. Create a "data dictionary" based on the data
#
# ---
#
# A data dictionary is an object that describes your data. This should contain the name of each variable (column), the type of the variable, your description of what the variable is, and the shape (rows and columns) of the entire dataset.

# %%
data_dictionary = {
    ('State','object'):'This includes 50 States, DC, and ALL',
    ('Rate', 'int'): 'Rate of something...',
    ('Verbal','int'): 'Average verbal score out of 800 for students in given state',
    ('Math','int'): 'Average math score out of 800 for studends in given state',
    'Dimensions':('52 rows by 4 columns')
}

data_dictionary
# Out:
# {'Dimensions': '52 rows by 4 columns',
#  ('Math', 'int'): 'Average math score out of 800 for studends in given state',
#  ('Rate', 'int'): 'Rate of something...',
#  ('State', 'object'): 'This includes 50 States, DC, and ALL',
#  ('Verbal',
#   'int'): 'Average verbal score out of 800 for students in given state'}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. Plot the data using seaborn
#
# ---
#
# ### 3.1 Using seaborn's `distplot`, plot the distributions for each of `Rate`, `Math`, and `Verbal`
#
# Set the keyword argument `kde=False`. This way you can actually see the counts within bins. You can adjust the number of bins to your liking.
#
# [Please read over the `distplot` documentation to learn about the arguments and fine-tune your chart if you want.](https://stanford.edu/~mwaskom/software/seaborn/generated/seaborn.distplot.html#seaborn.distplot)

# %%
fig = plt.figure(figsize = (8,6))
ax = fig.gca()
ax = sns.distplot(df['Math'],kde=False,norm_hist=True,bins=10)
ax.set_title('Distribution of SAT Math scores', fontsize=16)

plt.show()

# %%
fig = plt.figure(figsize = (8,6))
ax = fig.gca()
ax = sns.distplot(df['Verbal'],kde=False,norm_hist=True,bins=10)
ax.set_title('Distribution of SAT Verbal scores', fontsize=16)

# %%
fig = plt.figure(figsize = (8,6))
ax = fig.gca()
ax = sns.distplot(df['Rate'],kde=False,norm_hist=True,bins=10)
ax.set_title('Distribution of SAT Rates', fontsize=16)

# %% [markdown]
# ### 3.2 Using seaborn's `pairplot`, show the joint distributions for each of `Rate`, `Math`, and `Verbal`
#
# Explain what the visualization tells you about your data.
#
# [Please read over the `pairplot` documentation to fine-tune your chart.](https://stanford.edu/~mwaskom/software/seaborn/generated/seaborn.pairplot.html#seaborn.pairplot)

# %%
sns.pairplot(df)

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 4. Plot the data using built-in pandas functions.
#
# ---
#
# Pandas is very powerful and contains a variety of nice, built in plotting functions for your data. Read the documentation here to overview and understand the capabilities:
#
# http://pandas.pydata.org/pandas-docs/stable/visualization.html
#
# ### 4.1 Plot a stacked histogram with `Verbal` and `Math` using pandas

# %%
df[['Verbal', 'Math']].plot.hist(stacked=True)

# %% [markdown]
# ### 4.2 Plot `Verbal` and `Math` on the same chart using boxplots (pandas or seaborn)
#
# What are the benefits of using a boxplot as compared to a scatterplot or a histogram?
#
# What's wrong with plotting a box-plot of `Rate` on the same chart as `Math` and `Verbal`?

# %%
df[['Verbal', 'Math']].plot.box()

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 4.3 Plot `Verbal`, `Math`, and `Rate` appropriately on the same boxplot chart (pandas or seaborn)
#
# Think about how you might change the variables so that they would make sense on the same chart. Explain your rationale for the choices on the chart. You should strive to make the chart as intuitive as possible.

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 5. Create and examine subsets of the data
#
# ---
#
# For these questions you will practice **masking** in pandas. Recall that masking uses conditional statements to select portions of your DataFrame (through boolean operations under the hood.)
#
# Remember the distinction between DataFrame indexing functions in pandas:
#
#     .iloc[row, col] : row and column are specified by index, which are integers
#     .loc[row, col]  : row and column are specified by string "labels" (boolean arrays are allowed; useful for rows)
#     .ix[row, col]   : row and column indexers can be a mix of labels and integer indices
#
# For detailed reference and tutorial make sure to read over the pandas documentation:
#
# http://pandas.pydata.org/pandas-docs/stable/indexing.html
#
#
#
# ### 5.1 Find the list of states that have `Verbal` scores greater than the average of `Verbal` scores across states
#
# How many states are above the mean? What does this tell you about the distribution of `Verbal` scores?

# %%
verbal_mean_mask = (df['Verbal'] > df['Verbal'].mean())
df[verbal_mean_mask].describe()
df[verbal_mean_mask].info()
df[verbal_mean_mask]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24 entries, 26 to 50
# Data columns (total 4 columns):
# State     24 non-null object
# Rate      24 non-null int64
# Verbal    24 non-null int64
# Math      24 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 960.0+ bytes
#    State  Rate  Verbal  Math
# 26    CO    31     539   542
# 27    OH    26     534   439
# 28    MT    23     539   539
# 30    ID    17     543   542
# 31    TN    13     562   553
# 32    NM    13     551   542
# 33    IL    12     576   589
# 34    KY    12     550   550
# 35    WY    11     547   545
# 36    MI    11     561   572
# 37    MN     9     580   589
# 38    KS     9     577   580
# 39    AL     9     559   554
# 40    NE     8     562   568
# 41    OK     8     567   561
# 42    MO     8     577   577
# 43    LA     7     564   562
# 44    WI     6     584   596
# 45    AR     6     562   550
# 46    UT     5     575   570
# 47    IA     5     593   603
# 48    SD     4     577   582
# 49    ND     4     592   599
# 50    MS     4     566   551

# %% [markdown]
# ### 5.2 Find the list of states that have `Verbal` scores greater than the median of `Verbal` scores across states
#
# How does this compare to the list of states greater than the mean of `Verbal` scores? Why?

# %%
verbal_median_mask = (df['Verbal'] > df['Verbal'].median())
df[verbal_mean_mask].describe()
df[verbal_mean_mask].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24 entries, 26 to 50
# Data columns (total 4 columns):
# State     24 non-null object
# Rate      24 non-null int64
# Verbal    24 non-null int64
# Math      24 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 960.0+ bytes

# %% [markdown]
# ### 5.3 Create a column that is the difference between the `Verbal` and `Math` scores
#
# Specifically, this should be `Verbal - Math`.

# %%
df['Score_difference'] = df['Verbal']-df['Math']

# %% [markdown]
# ### 5.4 Create two new DataFrames showing states with the greatest difference between scores
#
# 1. Your first DataFrame should be the 10 states with the greatest gap between `Verbal` and `Math` scores where `Verbal` is greater than `Math`. It should be sorted appropriately to show the ranking of states.
# 2. Your second DataFrame will be the inverse: states with the greatest gap between `Verbal` and `Math` such that `Math` is greater than `Verbal`. Again, this should be sorted appropriately to show rank.
# 3. Print the header of both variables, only showing the top 3 states in each.

# %%
top_ten_verbal = df.sort_values('Score_difference').iloc[0:10,:]
top_ten_math = df.sort_values('Score_difference').iloc[-10:,:]
print top_ten_math.sort_values('Score_difference', ascending=False).head(3)
print '\n'
print top_ten_verbal.head(3)
# Out:
#    State  Rate  Verbal  Math  Score_difference
# 27    OH    26     534   439                95
# 29    WV    18     527   512                15
# 50    MS     4     566   551                15
#
#
#    State  Rate  Verbal  Math  Score_difference
# 21    HI    52     485   515               -30
# 23    CA    51     498   517               -19
# 1     NJ    81     499   513               -14

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 6. Examine summary statistics
#
# ---
#
# Checking the summary statistics for data is an essential step in the EDA process!
#
# ### 6.1 Create the correlation matrix of your variables (excluding `State`).
#
# What does the correlation matrix tell you?

# %%
df_2 = df.drop(['State'], axis = 1)
df_2.corr()
# Out:
#                       Rate    Verbal      Math  Score_difference
# Rate              1.000000 -0.886432 -0.773746         -0.101412
# Verbal           -0.886432  1.000000  0.899871          0.052600
# Math             -0.773746  0.899871  1.000000         -0.388219
# Score_difference -0.101412  0.052600 -0.388219          1.000000

# %% [markdown]
# ### 6.2 Use pandas'  `.describe()` built-in function on your DataFrame
#
# Write up what each of the rows returned by the function indicate.

# %%
df_2.describe()

# Count shows number of non-null observations
# Mean shows mean of column
# Standard deviation of column
# Min shows the minimum number of a column
# 25% shows the lower quartile of data
# 50% shows the median
# 75% shows the upper quartile of data
# Max shows the maximum number of a column
# Out:
#             Rate      Verbal        Math  Score_difference
# count  52.000000   52.000000   52.000000         52.000000
# mean   37.153846  532.019231  531.500000          0.519231
# std    27.301788   33.236225   36.014975         15.729939
# min     4.000000  482.000000  439.000000        -30.000000
# 25%     9.000000  501.000000  504.000000         -6.000000
# 50%    33.500000  526.500000  521.000000          0.000000
# 75%    63.500000  562.000000  555.750000          4.250000
# max    82.000000  593.000000  603.000000         95.000000

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 6.3 Assign and print the _covariance_ matrix for the dataset
#
# 1. Describe how the covariance matrix is different from the correlation matrix.
# 2. What is the process to convert the covariance into the correlation?
# 3. Why is the correlation matrix preferred to the covariance matrix for examining relationships in your data?

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 7. Load Iowa Liquor Sales dataset
#
# ---
#
# The state of Iowa provides many data sets on their website, including [this dataset](https://www.dropbox.com/sh/pf5n5sgfgiri3i8/AACkaMeL_i_WgZ00rpxOOcysa?dl=0) which contains transactions for all stores that have a class E liquor license. You can choose one of the following two scenarios.
#
# The data can also be found [directly on their website](https://data.iowa.gov/Economy/Iowa-Liquor-Sales/m3tr-qhgy), which allows you to explore it graphically and download it (though it doesn't work very well).
#
# NOTE: Some of you may have computer issues with the full dataset. In this case, feel free to use [this 10% dataset version of Iowa liquor sales](https://drive.google.com/file/d/0Bx2SHQGVqWaseDB4QU9ZSVFDY2M/view?usp=sharing). You may want to use it anyway to test and prototype your code since it will be faster, before running it on the full dataset.

# %%
iowa_file = '../../../DSI-SF-4-vinnietoor/datasets/Iowa_Liquor_sales_sample_10pct.csv'
df = pd.read_csv(iowa_file)

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 7.1 Do an initial overview of the data
#
# ---
#
# At the very least describe the columns/variables and the datatypes.

# %%
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270955 entries, 0 to 270954
# Data columns (total 18 columns):
# Date                     270955 non-null object
# Store Number             270955 non-null int64
# City                     270955 non-null object
# Zip Code                 270955 non-null object
# County Number            269878 non-null float64
# County                   269878 non-null object
# Category                 270887 non-null float64
# Category Name            270323 non-null object
# Vendor Number            270955 non-null int64
# Item Number              270955 non-null int64
# Item Description         270955 non-null object
# Bottle Volume (ml)       270955 non-null int64
# State Bottle Cost        270955 non-null object
# State Bottle Retail      270955 non-null object
# Bottles Sold             270955 non-null int64
# Sale (Dollars)           270955 non-null object
# Volume Sold (Liters)     270955 non-null float64
# Volume Sold (Gallons)    270955 non-null float64
# dtypes: float64(4), int64(5), object(9)
# memory usage: 37.2+ MB
#               Date  Store Number             City Zip Code  County Number  \
# 0       11/04/2015          3717           SUMNER    50674            9.0
# 1       03/02/2016          2614        DAVENPORT    52807           82.0
# 2       02/11/2016          2106      CEDAR FALLS    50613            7.0
# 3       02/03/2016          2501             AMES    50010           85.0
# 4       08/18/2015          3654          BELMOND    50421           99.0
# 5       04/20/2015          2569     CEDAR RAPIDS    52402           57.0
# 6       08/05/2015          2596          OTTUMWA    52501           90.0
# 7       06/25/2015          3456       CLEAR LAKE    50428           17.0
# 8       01/04/2016          4757        BONDURANT    50035           77.0
# 9       11/10/2015          4346       SHELLSBURG    52332            6.0
# 10      09/28/2015          2648  WEST DES MOINES    50265           77.0
# 11      10/28/2015          2600        OSKALOOSA    52577           62.0
# 12      01/22/2015          3858        DAVENPORT    52806           82.0
# 13      02/29/2016          4673       WEST POINT    52656           56.0
# 14      01/04/2016          2670       CORALVILLE    52241           52.0
# 15      06/10/2015          3717           SUMNER    50674            9.0
# 16      02/25/2016          2130         WATERLOO    50703            7.0
# 17      12/29/2015          2600        OSKALOOSA    52577           62.0
# 18      12/26/2015          4604           NEWTON    50208           50.0
# 19      03/04/2015          2614        DAVENPORT    52807           82.0
# 20      01/16/2015          2590     CEDAR RAPIDS    52402           57.0
# 21      01/13/2015          3942           TOLEDO    52342           86.0
# 22      03/24/2015          3981     SIOUX CENTER    51250           84.0
# 23      11/12/2015          4376       MASON CITY    50401           17.0
# 24      03/14/2016          2618     CEDAR RAPIDS    52402           57.0
# 25      02/03/2015          3390          MILFORD    51351           30.0
# 26      11/23/2015          3565        IOWA CITY    52246           52.0
# 27      04/21/2015          3963   COUNCIL BLUFFS    51501           78.0
# 28      12/01/2015          4375           GRIMES    50111           77.0
# 29      01/14/2015          2545        IOWA CITY    52245           52.0
# ...            ...           ...              ...      ...            ...
# 270925  01/05/2015          2837         WATERLOO    50702            7.0
# 270926  12/26/2015          2478          ALTOONA    50009           77.0
# 270927  08/31/2015          2633       DES MOINES    50320           77.0
# 270928  10/07/2015          3896        IOWA CITY    52240           52.0
# 270929  01/25/2016          5070           WILTON    52778           70.0
# 270930  10/13/2015          4634     CEDAR RAPIDS    52402           57.0
# 270931  05/26/2015          2602     WEBSTER CITY    50595           40.0
# 270932  06/18/2015          4604           NEWTON    50208           50.0
# 270933  02/26/2015          4987             AMES    50010           85.0
# 270934  03/18/2015          2623       SIOUX CITY    51104           97.0
# 270935  06/08/2015          5126       DES MOINES    50310           77.0
# 270936  03/31/2015          2552     CEDAR RAPIDS    52404           57.0
# 270937  01/27/2015          2553          CRESTON    50801           88.0
# 270938  04/29/2015          3890     CEDAR RAPIDS    52405           57.0
# 270939  05/04/2015          4876         HIAWATHA    52233           57.0
# 270940  01/21/2015          2523      CENTERVILLE    52544            4.0
# 270941  02/09/2015          4856           LISBON    52253           57.0
# 270942  06/15/2015          2512        IOWA CITY    52240           52.0
# 270943  10/21/2015          4438             AMES    50010           85.0
# 270944  03/22/2016          2620  WINDSOR HEIGHTS    50311           77.0
# 270945  06/11/2015          2627       DES MOINES    50310           77.0
# 270946  11/24/2015          5162        URBANDALE    50322           77.0
# 270947  05/12/2015          4375           GRIMES    50111           77.0
# 270948  04/08/2015          2545        IOWA CITY    52245           52.0
# 270949  07/21/2015          2529     CEDAR RAPIDS    52405           57.0
# 270950  12/22/2015          4057       DES MOINES    50316           77.0
# 270951  11/04/2015          5151        IDA GROVE    51445           47.0
# 270952  10/20/2015          5152         WATERLOO    50702            7.0
# 270953  11/20/2015          3562  WEST BURLINGTON    52655           29.0
# 270954  01/27/2015          4446        URBANDALE    50322           77.0
#
#                County   Category                       Category Name  \
# 0              Bremer  1051100.0                    APRICOT BRANDIES
# 1               Scott  1011100.0                    BLENDED WHISKIES
# 2          Black Hawk  1011200.0           STRAIGHT BOURBON WHISKIES
# 3               Story  1071100.0                  AMERICAN COCKTAILS
# 4              Wright  1031080.0                      VODKA 80 PROOF
# 5                Linn  1041100.0                   AMERICAN DRY GINS
# 6             Wapello  1051010.0             AMERICAN GRAPE BRANDIES
# 7         Cerro Gordo  1012100.0                   CANADIAN WHISKIES
# 8                Polk  1032080.0                      IMPORTED VODKA
# 9              Benton  1081315.0                   CINNAMON SCHNAPPS
# 10               Polk  1011250.0      SINGLE BARREL BOURBON WHISKIES
# 11            Mahaska  1071100.0                  AMERICAN COCKTAILS
# 12              Scott  1012100.0                   CANADIAN WHISKIES
# 13                Lee  1081300.0                 PEPPERMINT SCHNAPPS
# 14            Johnson  1031200.0                      VODKA FLAVORED
# 15             Bremer  1051100.0                    APRICOT BRANDIES
# 16         Black Hawk  1031100.0                     100 PROOF VODKA
# 17            Mahaska  1031200.0                      VODKA FLAVORED
# 18             Jasper  1081700.0         DISTILLED SPIRITS SPECIALTY
# 19              Scott  1012100.0                   CANADIAN WHISKIES
# 20               Linn  1031200.0                      VODKA FLAVORED
# 21               Tama  1012100.0                   CANADIAN WHISKIES
# 22              Sioux  1011100.0                    BLENDED WHISKIES
# 23        Cerro Gordo  1022100.0                             TEQUILA
# 24               Linn  1031080.0                      VODKA 80 PROOF
# 25          Dickinson  1011300.0                  TENNESSEE WHISKIES
# 26            Johnson  1012100.0                   CANADIAN WHISKIES
# 27      Pottawattamie  1011100.0                    BLENDED WHISKIES
# 28               Polk  1031080.0                      VODKA 80 PROOF
# 29            Johnson  1081600.0                     WHISKEY LIQUEUR
# ...               ...        ...                                 ...
# 270925     Black Hawk  1081200.0                      CREAM LIQUEURS
# 270926           Polk  1022100.0                             TEQUILA
# 270927           Polk  1031200.0                      VODKA FLAVORED
# 270928        Johnson  1031080.0                      VODKA 80 PROOF
# 270929      Muscatine  1031080.0                      VODKA 80 PROOF
# 270930           Linn  1031080.0                      VODKA 80 PROOF
# 270931       Hamilton  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 270932         Jasper  1011300.0                  TENNESSEE WHISKIES
# 270933          Story  1062310.0                          SPICED RUM
# 270934       Woodbury  1051110.0                 BLACKBERRY BRANDIES
# 270935           Polk  1011300.0                  TENNESSEE WHISKIES
# 270936           Linn  1022100.0                             TEQUILA
# 270937          Union  1082900.0  MISC. IMPORTED CORDIALS & LIQUEURS
# 270938           Linn  1031080.0                      VODKA 80 PROOF
# 270939           Linn  1031200.0                      VODKA FLAVORED
# 270940      Appanoose  1012200.0                     SCOTCH WHISKIES
# 270941           Linn  1031080.0                      VODKA 80 PROOF
# 270942        Johnson  1011100.0                    BLENDED WHISKIES
# 270943          Story  1011200.0           STRAIGHT BOURBON WHISKIES
# 270944           Polk  1081240.0               GREEN CREME DE MENTHE
# 270945           Polk  1062200.0    PUERTO RICO & VIRGIN ISLANDS RUM
# 270946           Polk  1031080.0                      VODKA 80 PROOF
# 270947           Polk  1062310.0                          SPICED RUM
# 270948        Johnson  1062300.0                        FLAVORED RUM
# 270949           Linn  1031100.0                     100 PROOF VODKA
# 270950           Polk  1022100.0                             TEQUILA
# 270951            Ida  1011200.0           STRAIGHT BOURBON WHISKIES
# 270952     Black Hawk  1011300.0                  TENNESSEE WHISKIES
# 270953     Des Moines  1082900.0  MISC. IMPORTED CORDIALS & LIQUEURS
# 270954           Polk  1031080.0                      VODKA 80 PROOF
#
#         Vendor Number  Item Number                       Item Description  \
# 0                  55        54436              Mr. Boston Apricot Brandy
# 1                 395        27605                                Tin Cup
# 2                  65        19067                               Jim Beam
# 3                 395        59154                1800 Ultimate Margarita
# 4                 297        35918                     Five O'clock Vodka
# 5                 205        31473                      New Amsterdam Gin
# 6                  85        52806                          Korbel Brandy
# 7                  65        10628                   Canadian Club Whisky
# 8                 370        34006           Absolut Swedish Vodka 80 Prf
# 9                  65        82610                     Dekuyper Hot Damn!
# 10                 65        19235       Knob Creek Single Barrel Reserve
# 11                 55        57148          Chi-Chi's Margarita W/tequila
# 12                 65        15248                   Windsor Canadian Pet
# 13                322        75211                          Kinky Liqueur
# 14                380        41705                  Uv Red (cherry) Vodka
# 15                 55        54436              Mr. Boston Apricot Brandy
# 16                297        35913                     Five O'clock Vodka
# 17                380        41989                          Uv Cake Vodka
# 18                434        75087                        Juarez Gold Dss
# 19                434        13638           Lord Calvert Canadian Whisky
# 20                971        41474                   44 North Huckleberry
# 21                115        11786                  Black Velvet Traveler
# 22                260        25606            Seagrams 7 Crown Bl Whiskey
# 23                395        89196  Jose Cuervo Especial Reposado Tequila
# 24                297        35926                 Five O'clock PET Vodka
# 25                 85        26827          Jack Daniels Old #7 Black Lbl
# 26                260        11290       Crown Royal Canadian Whisky Mini
# 27                434        24156                  Hawkeye Blend Whiskey
# 28                380        37338                           UV Vodka PET
# 29                260        66199                 Piehole Apple Pie Mini
# ...               ...          ...                                    ...
# 270925            260        68306             Emmets Irish Cream Liqueur
# 270926            410        89646                           Patron Anejo
# 270927            260        77699                        Smirnoff Orange
# 270928            300        36904                    Mccormick Vodka Pet
# 270929            380        37346                         Phillips Vodka
# 270930            297        35914                     Five O'clock Vodka
# 270931             65        85526        Dekuyper Signature Blue Curacao
# 270932             85        26828          Jack Daniels Old #7 Black Lbl
# 270933            260        43336         Captain Morgan Original Spiced
# 270934             55        55068           Mr. Boston Blackberry Brandy
# 270935             85        86670          Jack Daniel's Tennessee Honey
# 270936            395        89196  Jose Cuervo Especial Reposado Tequila
# 270937             85        64676      Chambord Liqueur Royale De France
# 270938            260        37994                  Smirnoff Vodka 80 Prf
# 270939            380        42002                          Uv Cake Vodka
# 270940            305         4936                   Famous Grouse Scotch
# 270941             55        35948       Fleischmann's Royal Vodka 80 Prf
# 270942             65        24466         Kessler Blend Whiskey Traveler
# 270943             65        19061                          Jim Beam Mini
# 270944            434        79336        Paramount Creme De Menthe/green
# 270945             55        44215                       Barton Light Rum
# 270946            301        38176                            Titos Vodka
# 270947            260        43334              Captain Morgan Spiced Rum
# 270948             35        43145               Bacardi Pineapple Fusion
# 270949            300        36887                        McCormick Vodka
# 270950            410        88291             Patron Tequila Silver Mini
# 270951            259        17956              Evan Williams Str Bourbon
# 270952             85        26826          Jack Daniels Old #7 Black Lbl
# 270953            192        65258                   Jagermeister Liqueur
# 270954            260        37993                  Smirnoff Vodka 80 Prf
#
#         Bottle Volume (ml) State Bottle Cost State Bottle Retail  \
# 0                      750             $4.50               $6.75
# 1                      750            $13.75              $20.63
# 2                     1000            $12.59              $18.89
# 3                     1750             $9.50              $14.25
# 4                     1750             $7.20              $10.80
# 5                     1750            $13.32              $19.98
# 6                      750             $6.66               $9.99
# 7                     1750            $15.75              $23.63
# 8                      750            $11.49              $17.24
# 9                     1000             $7.62              $11.43
# 10                     750            $26.24              $39.36
# 11                    1750             $6.00               $9.25
# 12                    1750             $8.92              $13.38
# 13                     750            $10.00              $15.00
# 14                    1000             $7.50              $11.25
# 15                     750             $4.50               $6.75
# 16                     200             $1.13               $1.70
# 17                     750             $6.50               $9.75
# 18                    1000             $4.92               $7.38
# 19                    1750             $9.97              $14.96
# 20                     750            $14.25              $21.38
# 21                     750             $5.23               $7.85
# 22                     750             $7.00              $10.50
# 23                     750            $10.49              $15.74
# 24                     750             $3.37               $5.06
# 25                    1000            $17.90              $26.85
# 26                     300             $7.35              $11.03
# 27                     750             $3.50               $5.25
# 28                    1750            $10.99              $16.49
# 29                     500             $4.90               $7.35
# ...                    ...               ...                 ...
# 270925                 750             $6.00               $9.00
# 270926                 750            $31.00              $46.50
# 270927                1000             $9.25              $13.88
# 270928                 375             $1.80               $2.70
# 270929                 750             $3.57               $5.36
# 270930                 375             $1.93               $2.90
# 270931                 750             $5.25               $7.88
# 270932                1750            $29.67              $44.51
# 270933                 750             $9.00              $13.50
# 270934                1750            $10.00              $15.00
# 270935                 750            $15.07              $22.61
# 270936                 750            $10.49              $15.74
# 270937                 750            $18.56              $27.84
# 270938                 375             $4.75               $7.13
# 270939                 500             $4.89               $7.34
# 270940                 750            $12.03              $18.05
# 270941                1750             $6.68              $10.27
# 270942                 750             $5.51               $8.27
# 270943                 500             $6.83              $10.25
# 270944                 750             $4.75               $7.13
# 270945                 100             $0.89               $1.34
# 270946                 750             $9.65              $14.48
# 270947                 375             $5.00               $7.50
# 270948                 750             $8.50              $12.75
# 270949                1000             $4.13               $6.20
# 270950                 300            $20.30              $30.45
# 270951                 750             $7.47              $11.21
# 270952                 750            $15.07              $22.61
# 270953                1750            $26.05              $39.08
# 270954                 200             $2.75               $4.13
#
#         Bottles Sold Sale (Dollars)  Volume Sold (Liters)  \
# 0                 12         $81.00                  9.00
# 1                  2         $41.26                  1.50
# 2                 24        $453.36                 24.00
# 3                  6         $85.50                 10.50
# 4                 12        $129.60                 21.00
# 5                  6        $119.88                 10.50
# 6                  3         $29.97                  2.25
# 7                  2         $47.26                  3.50
# 8                  4         $68.96                  3.00
# 9                  2         $22.86                  2.00
# 10                 6        $236.16                  4.50
# 11                 6         $55.50                 10.50
# 12                 1         $13.38                  1.75
# 13                12        $180.00                  9.00
# 14                12        $135.00                 12.00
# 15                 4         $27.00                  3.00
# 16                48         $81.60                  9.60
# 17                12        $117.00                  9.00
# 18                24        $177.12                 24.00
# 19                 6         $89.76                 10.50
# 20                 2         $42.76                  1.50
# 21                12         $94.20                  9.00
# 22                12        $126.00                  9.00
# 23                12        $188.88                  9.00
# 24                12         $60.72                  9.00
# 25                24        $644.40                 24.00
# 26                 1         $11.03                  0.30
# 27                 3         $15.75                  2.25
# 28                 6         $98.94                 10.50
# 29                 1          $7.35                  0.50
# ...              ...            ...                   ...
# 270925             4         $36.00                  3.00
# 270926             6        $279.00                  4.50
# 270927            12        $166.56                 12.00
# 270928            48        $129.60                 18.00
# 270929             4         $21.44                  3.00
# 270930            12         $34.80                  4.50
# 270931            12         $94.56                  9.00
# 270932             2         $89.02                  3.50
# 270933             3         $40.50                  2.25
# 270934             2         $30.00                  3.50
# 270935             3         $67.83                  2.25
# 270936            12        $188.88                  9.00
# 270937             1         $27.84                  0.75
# 270938             3         $21.39                  1.12
# 270939             6         $44.04                  3.00
# 270940             4         $72.20                  3.00
# 270941             6         $61.62                 10.50
# 270942            12         $99.24                  9.00
# 270943             1         $10.25                  0.50
# 270944             2         $14.26                  1.50
# 270945            48         $64.32                  4.80
# 270946             4         $57.92                  3.00
# 270947             6         $45.00                  2.25
# 270948             3         $38.25                  2.25
# 270949             3         $18.60                  3.00
# 270950             4        $121.80                  1.20
# 270951             3         $33.63                  2.25
# 270952             6        $135.66                  4.50
# 270953             6        $234.48                 10.50
# 270954             8         $33.04                  1.60
#
#         Volume Sold (Gallons)
# 0                        2.38
# 1                        0.40
# 2                        6.34
# 3                        2.77
# 4                        5.55
# 5                        2.77
# 6                        0.59
# 7                        0.92
# 8                        0.79
# 9                        0.53
# 10                       1.19
# 11                       2.77
# 12                       0.46
# 13                       2.38
# 14                       3.17
# 15                       0.79
# 16                       2.54
# 17                       2.38
# 18                       6.34
# 19                       2.77
# 20                       0.40
# 21                       2.38
# 22                       2.38
# 23                       2.38
# 24                       2.38
# 25                       6.34
# 26                       0.08
# 27                       0.59
# 28                       2.77
# 29                       0.13
# ...                       ...
# 270925                   0.79
# 270926                   1.19
# 270927                   3.17
# 270928                   4.76
# 270929                   0.79
# 270930                   1.19
# 270931                   2.38
# 270932                   0.92
# 270933                   0.59
# 270934                   0.92
# 270935                   0.59
# 270936                   2.38
# 270937                   0.20
# 270938                   0.30
# 270939                   0.79
# 270940                   0.79
# 270941                   2.77
# 270942                   2.38
# 270943                   0.13
# 270944                   0.40
# 270945                   1.27
# 270946                   0.79
# 270947                   0.59
# 270948                   0.59
# 270949                   0.79
# 270950                   0.32
# 270951                   0.59
# 270952                   1.19
# 270953                   2.77
# 270954                   0.42
#
# [270955 rows x 18 columns]

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 8. Clean the liquor dataset
#
# ---
#
# ### 8.1 Identify columns that you will need to convert and clean. Where and how is the data corrupted?
#
# Don't worry about converting the date column to a pandas/numpy "datetime" datatype, unless you want to (not required for these problems and is a challenging thing to work with in its own right.)

# %%
df['Date'] =pd.to_datetime(df.Date)
df.sort_values(by='Date')

df['Date'] =pd.to_datetime(df.Date)
df.sort_values(by='Date')

def try_to_convert(x):
    try:
        return float(x.replace('$',''))
    except:
        return np.nan
    
df['Sale (Dollars)'] = df['Sale (Dollars)'].map(try_to_convert)
df['State Bottle Cost'] = df['State Bottle Cost'].map(try_to_convert)
df['State Bottle Retail'] = df['State Bottle Retail'].map(try_to_convert)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270955 entries, 0 to 270954
# Data columns (total 18 columns):
# Date                     270955 non-null datetime64[ns]
# Store Number             270955 non-null int64
# City                     270955 non-null object
# Zip Code                 270955 non-null object
# County Number            269878 non-null float64
# County                   269878 non-null object
# Category                 270887 non-null float64
# Category Name            270323 non-null object
# Vendor Number            270955 non-null int64
# Item Number              270955 non-null int64
# Item Description         270955 non-null object
# Bottle Volume (ml)       270955 non-null int64
# State Bottle Cost        270955 non-null float64
# State Bottle Retail      270955 non-null float64
# Bottles Sold             270955 non-null int64
# Sale (Dollars)           0 non-null float64
# Volume Sold (Liters)     270955 non-null float64
# Volume Sold (Gallons)    270955 non-null float64
# dtypes: datetime64[ns](1), float64(7), int64(5), object(5)
# memory usage: 37.2+ MB

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 8.2 Perform more extensive cleaning of the dataset
#
# Cleaning of data can mean a lot more than just fixing strings and numbers in columns. There are often logical errors with data, useless or nonsensical categories, redundancy of information, outliers, and many more problems.
#
# This dataset has problems beyond just fixing the types of columns. Though resolving them may not be required for EDA and analysis, if you want experience with "deeper" cleaning of data this is a great dataset to start practicing with.
#
# Keep in mind that some types of "data cleaning" is subjective: it's not always a cut-and-dry conversion of type or removal of null values. Subjectivity when dealing with data is just a fact of life for a data scientist. This isn't a kind of programming where things are just right or wrong.

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 9. Filter/adjust the store data
#
# ---
#
# Some stores may have opened or closed in 2015. These stores will have incorrect yearly summary statistics since they were not open the full year. We need to filter them out or find another way to deal with the inconsistent numbers of months across stores.
#
# It is up to you how you want to deal with this problem.
#
# 1. Investigate problematic stores.
# 2. Decide on an approach to handle missing data for stores not open for the full 2015 year. Do you impute? Remove the stores? Something else?
# 3. Implement your plan.
# 4. Briefly report on what you did and why.

# %%
from datetime import datetime

df['Date'] = pd.to_datetime(df['Date'])
df_cleaned = df[(df['Date'] >= '2015-01-01') & (df['Date'] <= '2015-12-31')]
df_cleaned
df = df_cleaned
df
# Decided to keep only the stores with dates from January 1, 2015 through December 31, 2015 for consistency.
# Out:
#              Date  Store Number             City Zip Code  County Number  \
# 0      2015-11-04          3717           SUMNER    50674            9.0
# 4      2015-08-18          3654          BELMOND    50421           99.0
# 5      2015-04-20          2569     CEDAR RAPIDS    52402           57.0
# 6      2015-08-05          2596          OTTUMWA    52501           90.0
# 7      2015-06-25          3456       CLEAR LAKE    50428           17.0
# 9      2015-11-10          4346       SHELLSBURG    52332            6.0
# 10     2015-09-28          2648  WEST DES MOINES    50265           77.0
# 11     2015-10-28          2600        OSKALOOSA    52577           62.0
# 12     2015-01-22          3858        DAVENPORT    52806           82.0
# 15     2015-06-10          3717           SUMNER    50674            9.0
# 17     2015-12-29          2600        OSKALOOSA    52577           62.0
# 18     2015-12-26          4604           NEWTON    50208           50.0
# 19     2015-03-04          2614        DAVENPORT    52807           82.0
# 20     2015-01-16          2590     CEDAR RAPIDS    52402           57.0
# 21     2015-01-13          3942           TOLEDO    52342           86.0
# 22     2015-03-24          3981     SIOUX CENTER    51250           84.0
# 23     2015-11-12          4376       MASON CITY    50401           17.0
# 25     2015-02-03          3390          MILFORD    51351           30.0
# 26     2015-11-23          3565        IOWA CITY    52246           52.0
# 27     2015-04-21          3963   COUNCIL BLUFFS    51501           78.0
# 28     2015-12-01          4375           GRIMES    50111           77.0
# 29     2015-01-14          2545        IOWA CITY    52245           52.0
# 30     2015-04-01          4438             AMES    50010           85.0
# 31     2015-01-12          2555           KEOKUK    52632           56.0
# 32     2015-01-16          2549        INDIANOLA    50125           91.0
# 33     2015-01-13          2644       FORT DODGE    50501           94.0
# 34     2015-06-29          4195           TOLEDO    52342           86.0
# 35     2015-04-02          2626       DES MOINES    50311           77.0
# 36     2015-04-20          2532       DES MOINES    50317           77.0
# 37     2015-06-03          4520           HUXLEY    50124           85.0
# ...           ...           ...              ...      ...            ...
# 270923 2015-09-10          2616          CLINTON    52732           23.0
# 270924 2015-12-22          2500             AMES    50010           85.0
# 270925 2015-01-05          2837         WATERLOO    50702            7.0
# 270926 2015-12-26          2478          ALTOONA    50009           77.0
# 270927 2015-08-31          2633       DES MOINES    50320           77.0
# 270928 2015-10-07          3896        IOWA CITY    52240           52.0
# 270930 2015-10-13          4634     CEDAR RAPIDS    52402           57.0
# 270931 2015-05-26          2602     WEBSTER CITY    50595           40.0
# 270932 2015-06-18          4604           NEWTON    50208           50.0
# 270933 2015-02-26          4987             AMES    50010           85.0
# 270934 2015-03-18          2623       SIOUX CITY    51104           97.0
# 270935 2015-06-08          5126       DES MOINES    50310           77.0
# 270936 2015-03-31          2552     CEDAR RAPIDS    52404           57.0
# 270937 2015-01-27          2553          CRESTON    50801           88.0
# 270938 2015-04-29          3890     CEDAR RAPIDS    52405           57.0
# 270939 2015-05-04          4876         HIAWATHA    52233           57.0
# 270940 2015-01-21          2523      CENTERVILLE    52544            4.0
# 270941 2015-02-09          4856           LISBON    52253           57.0
# 270942 2015-06-15          2512        IOWA CITY    52240           52.0
# 270943 2015-10-21          4438             AMES    50010           85.0
# 270945 2015-06-11          2627       DES MOINES    50310           77.0
# 270946 2015-11-24          5162        URBANDALE    50322           77.0
# 270947 2015-05-12          4375           GRIMES    50111           77.0
# 270948 2015-04-08          2545        IOWA CITY    52245           52.0
# 270949 2015-07-21          2529     CEDAR RAPIDS    52405           57.0
# 270950 2015-12-22          4057       DES MOINES    50316           77.0
# 270951 2015-11-04          5151        IDA GROVE    51445           47.0
# 270952 2015-10-20          5152         WATERLOO    50702            7.0
# 270953 2015-11-20          3562  WEST BURLINGTON    52655           29.0
# 270954 2015-01-27          4446        URBANDALE    50322           77.0
#
#                County   Category                       Category Name  \
# 0              Bremer  1051100.0                    APRICOT BRANDIES
# 4              Wright  1031080.0                      VODKA 80 PROOF
# 5                Linn  1041100.0                   AMERICAN DRY GINS
# 6             Wapello  1051010.0             AMERICAN GRAPE BRANDIES
# 7         Cerro Gordo  1012100.0                   CANADIAN WHISKIES
# 9              Benton  1081315.0                   CINNAMON SCHNAPPS
# 10               Polk  1011250.0      SINGLE BARREL BOURBON WHISKIES
# 11            Mahaska  1071100.0                  AMERICAN COCKTAILS
# 12              Scott  1012100.0                   CANADIAN WHISKIES
# 15             Bremer  1051100.0                    APRICOT BRANDIES
# 17            Mahaska  1031200.0                      VODKA FLAVORED
# 18             Jasper  1081700.0         DISTILLED SPIRITS SPECIALTY
# 19              Scott  1012100.0                   CANADIAN WHISKIES
# 20               Linn  1031200.0                      VODKA FLAVORED
# 21               Tama  1012100.0                   CANADIAN WHISKIES
# 22              Sioux  1011100.0                    BLENDED WHISKIES
# 23        Cerro Gordo  1022100.0                             TEQUILA
# 25          Dickinson  1011300.0                  TENNESSEE WHISKIES
# 26            Johnson  1012100.0                   CANADIAN WHISKIES
# 27      Pottawattamie  1011100.0                    BLENDED WHISKIES
# 28               Polk  1031080.0                      VODKA 80 PROOF
# 29            Johnson  1081600.0                     WHISKEY LIQUEUR
# 30              Story  1041100.0                   AMERICAN DRY GINS
# 31                Lee  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 32             Warren  1031080.0                      VODKA 80 PROOF
# 33            Webster  1081305.0                      APPLE SCHNAPPS
# 34               Tama  1051120.0                     CHERRY BRANDIES
# 35               Polk  1082900.0  MISC. IMPORTED CORDIALS & LIQUEURS
# 36               Polk  1071100.0                  AMERICAN COCKTAILS
# 37              Story  1042100.0                   IMPORTED DRY GINS
# ...               ...        ...                                 ...
# 270923        Clinton  1032080.0                      IMPORTED VODKA
# 270924          Story  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 270925     Black Hawk  1081200.0                      CREAM LIQUEURS
# 270926           Polk  1022100.0                             TEQUILA
# 270927           Polk  1031200.0                      VODKA FLAVORED
# 270928        Johnson  1031080.0                      VODKA 80 PROOF
# 270930           Linn  1031080.0                      VODKA 80 PROOF
# 270931       Hamilton  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 270932         Jasper  1011300.0                  TENNESSEE WHISKIES
# 270933          Story  1062310.0                          SPICED RUM
# 270934       Woodbury  1051110.0                 BLACKBERRY BRANDIES
# 270935           Polk  1011300.0                  TENNESSEE WHISKIES
# 270936           Linn  1022100.0                             TEQUILA
# 270937          Union  1082900.0  MISC. IMPORTED CORDIALS & LIQUEURS
# 270938           Linn  1031080.0                      VODKA 80 PROOF
# 270939           Linn  1031200.0                      VODKA FLAVORED
# 270940      Appanoose  1012200.0                     SCOTCH WHISKIES
# 270941           Linn  1031080.0                      VODKA 80 PROOF
# 270942        Johnson  1011100.0                    BLENDED WHISKIES
# 270943          Story  1011200.0           STRAIGHT BOURBON WHISKIES
# 270945           Polk  1062200.0    PUERTO RICO & VIRGIN ISLANDS RUM
# 270946           Polk  1031080.0                      VODKA 80 PROOF
# 270947           Polk  1062310.0                          SPICED RUM
# 270948        Johnson  1062300.0                        FLAVORED RUM
# 270949           Linn  1031100.0                     100 PROOF VODKA
# 270950           Polk  1022100.0                             TEQUILA
# 270951            Ida  1011200.0           STRAIGHT BOURBON WHISKIES
# 270952     Black Hawk  1011300.0                  TENNESSEE WHISKIES
# 270953     Des Moines  1082900.0  MISC. IMPORTED CORDIALS & LIQUEURS
# 270954           Polk  1031080.0                      VODKA 80 PROOF
#
#         Vendor Number  Item Number      ...      Bottle Volume (ml)  \
# 0                  55        54436      ...                     750
# 4                 297        35918      ...                    1750
# 5                 205        31473      ...                    1750
# 6                  85        52806      ...                     750
# 7                  65        10628      ...                    1750
# 9                  65        82610      ...                    1000
# 10                 65        19235      ...                     750
# 11                 55        57148      ...                    1750
# 12                 65        15248      ...                    1750
# 15                 55        54436      ...                     750
# 17                380        41989      ...                     750
# 18                434        75087      ...                    1000
# 19                434        13638      ...                    1750
# 20                971        41474      ...                     750
# 21                115        11786      ...                     750
# 22                260        25606      ...                     750
# 23                395        89196      ...                     750
# 25                 85        26827      ...                    1000
# 26                260        11290      ...                     300
# 27                434        24156      ...                     750
# 28                380        37338      ...                    1750
# 29                260        66199      ...                     500
# 30                434        31654      ...                     375
# 31                 65        73533      ...                     750
# 32                297        35918      ...                    1750
# 33                 65        82607      ...                    1000
# 34                434        55246      ...                     750
# 35                192        65254      ...                     375
# 36                285        56957      ...                    1000
# 37                260        28866      ...                     750
# ...               ...          ...      ...                     ...
# 270923             35        34422      ...                    1000
# 270924            322        75212      ...                     500
# 270925            260        68306      ...                     750
# 270926            410        89646      ...                     750
# 270927            260        77699      ...                    1000
# 270928            300        36904      ...                     375
# 270930            297        35914      ...                     375
# 270931             65        85526      ...                     750
# 270932             85        26828      ...                    1750
# 270933            260        43336      ...                     750
# 270934             55        55068      ...                    1750
# 270935             85        86670      ...                     750
# 270936            395        89196      ...                     750
# 270937             85        64676      ...                     750
# 270938            260        37994      ...                     375
# 270939            380        42002      ...                     500
# 270940            305         4936      ...                     750
# 270941             55        35948      ...                    1750
# 270942             65        24466      ...                     750
# 270943             65        19061      ...                     500
# 270945             55        44215      ...                     100
# 270946            301        38176      ...                     750
# 270947            260        43334      ...                     375
# 270948             35        43145      ...                     750
# 270949            300        36887      ...                    1000
# 270950            410        88291      ...                     300
# 270951            259        17956      ...                     750
# 270952             85        26826      ...                     750
# 270953            192        65258      ...                    1750
# 270954            260        37993      ...                     200
#
#         State Bottle Cost  State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 0                    4.50                 6.75            12             NaN
# 4                    7.20                10.80            12             NaN
# 5                   13.32                19.98             6             NaN
# 6                    6.66                 9.99             3             NaN
# 7                   15.75                23.63             2             NaN
# 9                    7.62                11.43             2             NaN
# 10                  26.24                39.36             6             NaN
# 11                   6.00                 9.25             6             NaN
# 12                   8.92                13.38             1             NaN
# 15                   4.50                 6.75             4             NaN
# 17                   6.50                 9.75            12             NaN
# 18                   4.92                 7.38            24             NaN
# 19                   9.97                14.96             6             NaN
# 20                  14.25                21.38             2             NaN
# 21                   5.23                 7.85            12             NaN
# 22                   7.00                10.50            12             NaN
# 23                  10.49                15.74            12             NaN
# 25                  17.90                26.85            24             NaN
# 26                   7.35                11.03             1             NaN
# 27                   3.50                 5.25             3             NaN
# 28                  10.99                16.49             6             NaN
# 29                   4.90                 7.35             1             NaN
# 30                   1.99                 2.99             3             NaN
# 31                  12.07                18.11             2             NaN
# 32                   7.20                10.80            12             NaN
# 33                   7.62                11.43            12             NaN
# 34                   5.38                 8.07             2             NaN
# 35                   6.52                 9.78             4             NaN
# 36                   5.28                 7.92            12             NaN
# 37                  12.25                18.38            12             NaN
# ...                   ...                  ...           ...             ...
# 270923              22.50                33.75            12             NaN
# 270924               7.47                11.21             2             NaN
# 270925               6.00                 9.00             4             NaN
# 270926              31.00                46.50             6             NaN
# 270927               9.25                13.88            12             NaN
# 270928               1.80                 2.70            48             NaN
# 270930               1.93                 2.90            12             NaN
# 270931               5.25                 7.88            12             NaN
# 270932              29.67                44.51             2             NaN
# 270933               9.00                13.50             3             NaN
# 270934              10.00                15.00             2             NaN
# 270935              15.07                22.61             3             NaN
# 270936              10.49                15.74            12             NaN
# 270937              18.56                27.84             1             NaN
# 270938               4.75                 7.13             3             NaN
# 270939               4.89                 7.34             6             NaN
# 270940              12.03                18.05             4             NaN
# 270941               6.68                10.27             6             NaN
# 270942               5.51                 8.27            12             NaN
# 270943               6.83                10.25             1             NaN
# 270945               0.89                 1.34            48             NaN
# 270946               9.65                14.48             4             NaN
# 270947               5.00                 7.50             6             NaN
# 270948               8.50                12.75             3             NaN
# 270949               4.13                 6.20             3             NaN
# 270950              20.30                30.45             4             NaN
# 270951               7.47                11.21             3             NaN
# 270952              15.07                22.61             6             NaN
# 270953              26.05                39.08             6             NaN
# 270954               2.75                 4.13             8             NaN
#
#         Volume Sold (Liters)  Volume Sold (Gallons)  yearly_liquor_sales  \
# 0                       9.00                   2.38                27.00
# 4                      21.00                   5.55                43.20
# 5                      10.50                   2.77                39.96
# 6                       2.25                   0.59                 9.99
# 7                       3.50                   0.92                15.76
# 9                       2.00                   0.53                 7.62
# 10                      4.50                   1.19                78.72
# 11                     10.50                   2.77                19.50
# 12                      1.75                   0.46                 4.46
# 15                      3.00                   0.79                 9.00
# 17                      9.00                   2.38                39.00
# 18                     24.00                   6.34                59.04
# 19                     10.50                   2.77                29.94
# 20                      1.50                   0.40                14.26
# 21                      9.00                   2.38                31.44
# 22                      9.00                   2.38                42.00
# 23                      9.00                   2.38                63.00
# 25                     24.00                   6.34               214.80
# 26                      0.30                   0.08                 3.68
# 27                      2.25                   0.59                 5.25
# 28                     10.50                   2.77                33.00
# 29                      0.50                   0.13                 2.45
# 30                      1.12                   0.30                 3.00
# 31                      1.50                   0.40                12.08
# 32                     21.00                   5.55                43.20
# 33                     12.00                   3.17                45.72
# 34                      1.50                   0.40                 5.38
# 35                      1.50                   0.40                13.04
# 36                     12.00                   3.17                31.68
# 37                      9.00                   2.38                73.56
# ...                      ...                    ...                  ...
# 270923                 12.00                   3.17               135.00
# 270924                  1.00                   0.26                 7.48
# 270925                  3.00                   0.79                12.00
# 270926                  4.50                   1.19                93.00
# 270927                 12.00                   3.17                55.56
# 270928                 18.00                   4.76                43.20
# 270930                  4.50                   1.19                11.64
# 270931                  9.00                   2.38                31.56
# 270932                  3.50                   0.92                29.68
# 270933                  2.25                   0.59                13.50
# 270934                  3.50                   0.92                10.00
# 270935                  2.25                   0.59                22.62
# 270936                  9.00                   2.38                63.00
# 270937                  0.75                   0.20                 9.28
# 270938                  1.12                   0.30                 7.14
# 270939                  3.00                   0.79                14.70
# 270940                  3.00                   0.79                24.08
# 270941                 10.50                   2.77                21.54
# 270942                  9.00                   2.38                33.12
# 270943                  0.50                   0.13                 3.42
# 270945                  4.80                   1.27                21.60
# 270946                  3.00                   0.79                19.32
# 270947                  2.25                   0.59                15.00
# 270948                  2.25                   0.59                12.75
# 270949                  3.00                   0.79                 6.21
# 270950                  1.20                   0.32                40.60
# 270951                  2.25                   0.59                11.22
# 270952                  4.50                   1.19                45.24
# 270953                 10.50                   2.77                78.18
# 270954                  1.60                   0.42                11.04
#
#         store_profit  yearly_sales
# 0              27.00         81.00
# 4              43.20        129.60
# 5              39.96        119.88
# 6               9.99         29.97
# 7              15.76         47.26
# 9               7.62         22.86
# 10             78.72        236.16
# 11             19.50         55.50
# 12              4.46         13.38
# 15              9.00         27.00
# 17             39.00        117.00
# 18             59.04        177.12
# 19             29.94         89.76
# 20             14.26         42.76
# 21             31.44         94.20
# 22             42.00        126.00
# 23             63.00        188.88
# 25            214.80        644.40
# 26              3.68         11.03
# 27              5.25         15.75
# 28             33.00         98.94
# 29              2.45          7.35
# 30              3.00          8.97
# 31             12.08         36.22
# 32             43.20        129.60
# 33             45.72        137.16
# 34              5.38         16.14
# 35             13.04         39.12
# 36             31.68         95.04
# 37             73.56        220.56
# ...              ...           ...
# 270923        135.00        405.00
# 270924          7.48         22.42
# 270925         12.00         36.00
# 270926         93.00        279.00
# 270927         55.56        166.56
# 270928         43.20        129.60
# 270930         11.64         34.80
# 270931         31.56         94.56
# 270932         29.68         89.02
# 270933         13.50         40.50
# 270934         10.00         30.00
# 270935         22.62         67.83
# 270936         63.00        188.88
# 270937          9.28         27.84
# 270938          7.14         21.39
# 270939         14.70         44.04
# 270940         24.08         72.20
# 270941         21.54         61.62
# 270942         33.12         99.24
# 270943          3.42         10.25
# 270945         21.60         64.32
# 270946         19.32         57.92
# 270947         15.00         45.00
# 270948         12.75         38.25
# 270949          6.21         18.60
# 270950         40.60        121.80
# 270951         11.22         33.63
# 270952         45.24        135.66
# 270953         78.18        234.48
# 270954         11.04         33.04
#
# [218594 rows x 21 columns]

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Examine liquor profits
#
# ---
#
# You are a data scientist in residence at the Iowa State tax board. The Iowa State legislature is considering changes in the liquor tax rates and has assigned you to the project.
#
# ### 10.1 Calculate yearly liquor sales for each store in 2015.

# %%
df['yearly_sales'] = (df['Bottles Sold'] * df['State Bottle Retail']) 
# I know this is only for one day of sales. Not sure how to

# %% [markdown]
# ### 10.2 Calculate the profit each store is making in 2015.

# %%
df['store_profit'] = (df['Bottles Sold']*df['State Bottle Retail']) - (df['Bottles Sold']*df['State Bottle Cost'])

# %% [markdown]
# ### 10.3 Investigate which Iowa counties are making the most profit on liquor per gallon in 2015.

# %%
df_iowa_counties = df.groupby('S')

# %% [markdown]
# ### 10.4 Create a broader category for liquor type.
#
# Liquor types are pretty granular in this dataset. Create a column that categorizes these types into a smaller amount of categories. The categories you decide on are up to you.

# %% [markdown]
# ### 10.5 Do relationships exist between the broader liquor type and profit?

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 11. Proposing a new liquor tax
#
# ---
#
# ### The tax board wants to design a tax or taxes that affect larger stores more than smaller "mom and pop" stores.
#
# Based on your investigations into the data, come up with a way you could design a tax that achieves this goal **without explicitly taxing stores based on size or county critera.** The liqour board does not want to obviously punish larger stores or speific counties for fear of backlash, but is willing to tax hard alcohol more than beer, for example.
#
# Feel free to do more EDA if it helps.
#
# Your report should describe whether such a tax is possible or not, and the specifics of what the tax will target/do.

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 12. Time-related effects
#
# ---
#
# You could imagine that liquor sales might be affected by a variety of effects related to time. Do people buy more beer in the summer? Do liquor sales skyrocket in december? Do people buy less liquor on Tuesdays?
#
# You have the date of sales in your dataset, which you can use to pull out time components.
#
# 1. Come up with 2 different hypotheses about how liquor sales may vary with time-related variables.
# 2. Create a visualization exploring each hypothesis.
# 3. Write brief concluding remarks on what you observed.
